# %% [markdown]
# 1. What is Simple Linear Regression (SLR)? Explain its purpose.
#   - SLR is a regression model used to predict continuous value and have only one independent variable.
#
# 2. What are the key assumptions of Simple Linear Regression?
#   - There should be only one independent variable.
#   - Both variables should have linear relationship.
#   - Variance of error should be constant.
#
# 3. Write the mathematical equation for a simple linear regression model and explain each term.
#   - y = mx + c
#   - y is the predicted value.
#   - m is slope of the line.
#   - c is intercept of the line.
#   - x is value of independent variable.
#
# 4. Provide a real-world example where simple linear regression can be applied.
#   - SLR can be used on dataset of marks obtained by number of hours studied by student.
#
# 5. What is the method of least squares in linear regression?
#   - least squares in linear regression is method used to find best line by minimizing the error.
#
# 6. What is Logistic Regression? How does it differ from Linear Regression?
#   - Logistic Regression is a classification model used to predict discrete values.
#   - Logistic uses sigmoid shape.
#   - Linear Regression is a regression model used to predict continuous values.
#   - Linear uses straight line.
#
# 7. Name and briefly describe three common evaluation metrics for regression models.
#   - Mean Absolute Error: Average of absolute differences for actual and predicted.
#   - Mean Squared Error: Average of squared differences for actual and predicted.
#   - R square: Measures how well the model explains variance in prediction.
#
# 8. What is the purpose of the R-squared metric in regression analysis?
#   - R-squared metric is used to measure how well the model explains variance in prediction.
#
# 10. How do you interpret the coefficients in a simple linear regression model?
#   - In y = mx+c, for every 1 unit increase in x, y changes by m units.

# %%
# 9. Write Python code to fit a simple linear regression model using scikit-learn
# and print the slope and intercept.
import pandas as pd

df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
X = df[["area"]]
y = df["price"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4, 1), (1, 1), (4,), (1,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"slope is {model.coef_[0]}")
print(f"intercept is {model.intercept_}")
# Out:
# slope is 135.34482758620692
# intercept is 183362.06896551716
