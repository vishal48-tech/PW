# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#     - Interpreted languages executes code line by line.
#     - Compiled languages convert whole code into byte code then executes it.
#
# 2. What is exception handling in Python?
#     - While writing code we may get error. Error stops the execution of code. Exception handling is used so that code keep executing even after error occurs.
#
# 3. What is the purpose of the finally block in exception handling?
#     - finally block is executed either exception occurs or not in try--except.
#
# 4. What is logging in Python?
#     - logging means recording messages which is used for debugging and monitoring.
#
# 5. What is the significance of the __del__ method in Python?
#     - It is important to delete an object manually or python removes it when no reference remains.
#
# 6. What is the difference between import and from ... import in Python?
#     - import used to import the module
#     - from -- import used to import a single or multiple functions from module
#
# 7.  How can you handle multiple exceptions in Python?
#     - We can use multiple except blocks to handle multiple exceptions.
#
# 8. What is the purpose of the with statement when handling files in Python?
#     - using with statement we don't have to close file manually.
#
# 9. What is the difference between multithreading and multiprocessing?
#     - a processor running multiple threads is called multithreading.
#     - Threads running in multiple processors is called multiprocessing.
#
# 10.  What are the advantages of using logging in a program?
#     - We can use it to monitor how the program behaves and debug if any error occurs.
#
# 11. What is memory management in Python?
#     - Memory management means how Python allocates, uses, and frees memory (RAM) for your program while it runs.
#
# 12. What are the basic steps involved in exception handling in Python?
#     - try block then except block
#
# 13. Why is memory management important in Python?
#     - Memory management is important because it ensures your program runs efficiently, doesn’t crash, doesn’t waste system resources.
#
# 14. What is the role of try and except in exception handling?
#     - Error handling, so code can run even after error occurs.
#
# 15. How does Python's garbage collection system work?
#     - Python's garbage collection deletes non reference objects to free memory.
#
# 16. What is the purpose of the else block in exception handling?
#     - else block executes if try executes successfully.
#
# 17. What are the common logging levels in Python?
#     - debug, info, warning, error, critical
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#     - os.fork() is a low-level Unix-only function that directly creates a child process by duplicating the current one, while multiprocessing is a high-level, cross-platform module that simplifies process creation and communication for parallel execution.
#
# 19.  What is the importance of closing a file in Python?
#     - closing file saves memory leak, thus memory usage is saved for other code.
#
# 20. What is the difference between file.read() and file.readline() in Python?
#     - file.read() gets the whole file data
#     - file.readline() gets single line from file
#
# 21. What is the logging module in Python used for?
#     - logging module is used for logging.
#
# 22. What is the os module in Python used for in file handling?
#     - os module can be used to get cwd, create or delete directories, etc.
#
# 23. What are the challenges associated with memory management in Python?
#     - Challenges in Python’s memory management include circular references, memory leaks, and high memory usage due to dynamic typing and object overhead.
#
# 24. How do you raise an exception manually in Python?
#     - raise ValueError("Invalid input")
#
# 25. Why is it important to use multithreading in certain applications?
#     - Multithreading is important because it improves performance, responsiveness, and efficiency by allowing multiple tasks to run concurrently.

# %%
# 1. How can you open a file for writing in Python and write a string to it?
with open("file.txt", "w") as f:
    f.write("Hello")

# %%
# 2. Write a Python program to read the contents of a file and print each line
with open("file.txt", "r") as f:
    data = f.readlines()
    for line in data:
        print(line)
# Out:
# Hello

# %%
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
    with open("file.txt", "r") as f:
        pass
except FileNotFoundError as fnfe:
    print(fnfe)

# %%
#4. Write a Python script that reads from one file and writes its content to another file
with open("file.txt", "r") as f:
    data = f.read()

with open("file2.txt", "w") as f:
    f.write(data)

# %%
# 5.How would you catch and handle division by zero error in Python?
try:
    print(5/0)
except ZeroDivisionError as zde:
    print(zde)
# Out:
# division by zero

# %%
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

logging.basicConfig(filename="div_error.log")
try:
    print(5/0)
except ZeroDivisionError as zde:
    logging.error(zde)

# %%
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging

logging.basicConfig(filename="program.log")
logging.info("Information")
logging.error("Error")
logging.warning("Warning")

# %%
# 8. Write a program to handle a file opening error using exception handling
try:
    with open("file.txt", "r") as f:
        pass
except Exception as e:
    print(e)

# %%
# 9. How can you read a file line by line and store its content in a list in Python?
with open("file.txt", "r") as f:
    data = f.readlines()

# %%
# 10. How can you append data to an existing file in Python?
with open("file.txt", "a") as f:
    f.write("\nWorld")

# %%
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist
dict = {"name": "Shiv", "age": 1800353}

try:
    print(dict["class"])
except KeyError as ke:
    print(ke)
# Out:
# 'class'

# %%
# 12.  Write a program that demonstrates using multiple except blocks to handle different types of exceptions
l1 = [5,2,8,9]
try:
    for i in range(10):
        print(i/0)
except ZeroDivisionError as zde:
    print(zde)
except IndexError as ie:
    print(ie)
# Out:
# division by zero

# %%
# 13. How would you check if a file exists before attempting to read it in Python?
import os

if os.path.exists("file.txt"): 
    try:
        with open("file.txt", "r") as f:
            pass
    except Exception as e:
        print(e)

# %%
# 14. Write a program that uses the logging module to log both informational and error messages
import logging

logging.basicConfig(filename="program.log")
logging.info("Information")
logging.error("Error")

# %%
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty
import os

file_path = "file.txt"

if os.path.exists(file_path):
    if os.path.getsize(file_path) > 0:
        with open(file_path, "r") as f:
            content = f.read()
            print("File content:\n", content)
    else:
        print("The file is empty.")
else:
    print("The file does not exist.")
# Out:
# File content:
#  Hello
# World

# %%
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program?
# pip install memory-profiler

from memory_profiler import profile

@profile
def create_list():
    my_list = [i for i in range(1000000)]
    return my_list

if __name__ == "__main__":
    create_list()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.
l1 = [4, 6, 9, 1, 2]

with open("numbers.txt", "w") as f:
    for i in l1:
        f.write(f"{str(i)}\n")

# %%
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler

# Create logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.INFO)

# Create a rotating file handler (max 1MB, keep 3 backups)
handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

logger.addHandler(handler)

# Example usage
logger.info("This is an info message")
logger.error("This is an error message")

# %%
# 19. Write a program that handles both IndexError and KeyError using a try-except blockF
my_list = [10, 20, 30]
my_dict = {"a": 1, "b": 2}

try:
    print(my_list[5])
    print(my_dict["c"])
except IndexError as ie:
    print(ie)
except KeyError as ke:
    print(ke)
# Out:
# list index out of range

# %%
# 20. How would you open a file and read its contents using a context manager in Python?
with open("file.txt", "r") as f:
    data = f.read()

# %%
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word?
with open("file.txt", "r") as f:
    data = f.read()
    print(data.count("Hello"))
# Out:
# 1

# %%
# 22. How can you check if a file is empty before attempting to read its contents?
import os

file_path = "file.txt"

if os.path.exists(file_path) and os.path.getsize(file_path) > 0:
    with open(file_path, "r") as f:
        content = f.read()
        print(content)
else:
    print("File is empty or does not exist.")
# Out:
# Hello
# World

# %%
# 23. Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(filename="file_handle.log")
try:
    with open("file.txt", "r") as f:
        data = f.read()
except FileNotFoundError as fnfe:
    logging.error(fnfe)
except Exception as e:
    logging.error(e)
